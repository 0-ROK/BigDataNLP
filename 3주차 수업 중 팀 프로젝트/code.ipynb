# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# !pip install finance-datareader
# !pip install -U finance-datareader # 업데이트

# %%
# import FinanceDataReader as fdr 
# finance_df = fdr.DataReader(symbol='036570', start='2021') # NC, 2020년~현재
# finance_df

finance_df = pd.read_csv('/content/drive/MyDrive/한밭대학교/빅데이터분석/03-05. Statistical Analysis/3주차 수업 중 팀 프로젝트/linege-stock-data.csv', encoding='cp949')

finance_df
# Out:
#           date  num_search  stock_price  NC Soft: (대한민국)  김택진: (대한민국)  \
# 0   2021-03-21          38       932000                7           45
# 1   2021-03-28          39       834000               15           30
# 2   2021-04-04          36       885000                2           15
# 3   2021-04-11          31       906000                7           22
# 4   2021-04-18          32       894000                3           10
# 5   2021-04-25          27       861000                7            2
# 6   2021-05-02          27       820000                5            3
# 7   2021-05-09          26       850000               12            7
# 8   2021-05-16          29       823000                5           10
# 9   2021-05-23          26       856000                2           17
# 10  2021-05-30          29       854000                2           10
# 11  2021-06-06          30       858000               10            2
# ...

# %%
fig = plt.figure(figsize=(10,6))
ax1 = fig.add_subplot(111)

ax1.plot(finance_df['stock_price'])

plt.show()

# %% [markdown]
# 트렌드 데이터와 스톡 데이터 엑셀로 병합함.

# %%
fig = plt.figure(figsize=(20, 10))
ax1 = fig.add_subplot(111)
ax2 = ax1.twinx()
